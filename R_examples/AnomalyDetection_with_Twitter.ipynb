# %% [markdown]
# # Low Level Anomaly Detection

# %%
# DCMP-1

# %%
library(tidyverse)

library(outliers)

library(expsmooth)

library(ggplot2)

# %%
library(devtools)

devtools::install_github("twitter/AnomalyDetection")

library(AnomalyDetection)
# Out:
# Skipping install of 'AnomalyDetection' from a github remote, the SHA1 (1f5deaa1) has not changed since last install.
#   Use `force = TRUE` to force installation

# %% [markdown]
# # Nitrate

# %% [markdown]
# ```
# > print(river)
#     index nitrate    months
# 1       1   1.581   January
# 2       2   1.323  February
# 3       3   1.140     March
# 4       4   1.245     April
# 5       5   1.072       May
# 6       6   1.483      June
# 7       7   1.162      July
# 8       8   1.304    August
# 9       9   1.140 September
# 10     10   1.118   October
# 11     11   1.342  November
# 12     12   1.245  December
# 13     13   1.204   January
# 14     14   1.140  February
# 15     15   1.204     March
# 16     16   1.118     April
# 17     17   1.025       May
# 18     18   1.118      June
# 19     19   1.285      July
# 20     20   1.140    August
# 21     21   0.949 September
# 22     22   0.922   October
# 23     23   0.949  November
# 24     24   1.118  December
# 25     25   1.265   January
# 26     26   1.095  February
# 27     27   1.183     March
# 28     28   1.162     April
# 29     29   1.118       May
# 30     30   1.285      June
# 31     31   1.049      July
# 32     32   0.922    August
# 33     33   0.775 September
# 34     34   0.866   October
# 35     35   0.922  November
# 36     36   1.643  December
# 37     37   1.323   January
# 38     38   1.285  February
# 39     39   1.095     March
# 40     40   1.049     April
# 41     41   1.095       May
# 42     42   0.922      June
# 43     43   0.866      July
# 44     44   1.049    August
# 45     45   0.922 September
# 46     46   1.095   October
# 47     47   1.183  November
# 48     48   1.304  December
# 49     49   1.162   January
# 50     50   1.225  February
# 51     51   1.285     March
# 52     52   1.072     April
# 53     53   1.533       May
# 54     54   1.095      June
# 55     55   1.396      July
# 56     56   1.025    August
# 57     57   0.922 September
# 58     58   0.949   October
# 59     59   1.118  November
# 60     60   1.342  December
# 61     61   1.360   January
# 62     62   1.360  February
# 63     63   1.204     March
# 64     64   1.265     April
# 65     65   1.000       May
# 66     66   1.183      June
# 67     67   1.025      July
# 68     68   0.866    August
# 69     69   1.072 September
# 70     70   1.049   October
# 71     71   1.049  November
# 72     72   1.049  December
# 73     73   1.095   January
# 74     74   1.183  February
# 75     75   1.095     March
# 76     76   0.975     April
# 77     77   1.118       May
# 78     78   0.975      June
# 79     79   1.049      July
# 80     80   0.837    August
# 81     81   0.922 September
# 82     82   1.118   October
# 83     83   1.072  November
# 84     84   1.204  December
# 85     85   0.975   January
# 86     86   1.095  February
# 87     87   1.049     March
# 88     88   0.866     April
# 89     89   0.922       May
# 90     90   1.049      June
# 91     91   1.127      July
# 92     92   1.072    August
# 93     93   0.975 September
# 94     94   1.049   October
# 95     95   1.183  November
# 96     96   1.245  December
# 97     97   1.225   January
# 98     98   1.225  February
# 99     99   1.265     March
# 100   100   1.118     April
# 101   101   1.140       May
# 102   102   1.072      June
# 103   103   1.095      July
# 104   104   0.671    August
# 105   105   1.183 September
# 106   106   0.949   October
# 107   107   1.162  November
# 108   108   1.095  December
# 109   109   1.323   January
# 110   110   1.342  February
# 111   111   1.277     March
# 112   112   1.015     April
# 113   113   1.000       May
# 114   114   0.922      June
# 115   115   0.894      July
# 116   116   1.000    August
# 117   117   1.049 September
# 118   118   0.922   October
# 253   253   1.187   January
# 254   254   1.054  February
# 255   255   1.079     March
# 256   256   0.997     April
# 257   257   0.851       May
# 258   258   0.803      June
# 259   259   0.971      July
# 260   260   1.025    August
# 261   261   1.086 September
# 262   262   1.114   October
# 263   263   1.068  November
# 264   264   1.091  December
# 265   265   1.034   January
# 266   266   0.871  February
# 267   267   0.781     March
# 268   268   0.865     April
# 269   269   0.700       May
# 270   270   0.673      June
# 271   271   0.881      July
# 272   272   0.782    August
# 273   273   0.970 September
# 274   274   1.044   October
# 275   275   1.170  November
# 276   276   1.196  December
# 277   277   1.091   January
# 278   278   1.068  February
# 279   279   0.967     March
# 280   280   0.823     April
# 281   281   0.730       May
# 282   282   0.693      June
# 283   283   0.788      July
# 284   284   1.095    August
# 285   285   1.183 September
# 286   286   0.996   October
# 287   287   1.105  November
# 288   288   0.939  December
# 289   289   0.914   January
# 290   290   0.813  February
# 291   291   0.775     March
# ```

# %%
river <- read.csv(file = 'e://river_data.csv', sep = ',', header = TRUE)

head(river)
# Out:
#   ï..index nitrate months
# 1 1        1.581   January
# 2 2        1.323   February
# 3 3        1.140   March
# 4 4        1.245   April
# 5 5        1.072   May
# 6 6        1.483   June

# %%
names(river)
# Out:
# [1] "ï..index" "nitrate"  "months"

# %%
# Explore contents of dataset
head(river)

# Summary statistics of river nitrate concentrations
summary(river$nitrate)

# Plot the distribution of nitrate concentration
boxplot(river$nitrate)
# Out:
#   ï..index nitrate months
# 1 1        1.581   January
# 2 2        1.323   February
# 3 3        1.140   March
# 4 4        1.245   April
# 5 5        1.072   May
# 6 6        1.483   June
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  0.5920  0.9485  1.0680  1.0649  1.1700  1.8970
# plot without title

# %%
river$index <- river$ï..index

# %%
# Add a Nitrate concentration label 
hist(river$nitrate, xlab = "Nitrate concentration")
# Out:
# Plot with title "Histogram of river$nitrate"

# %%
# yep, looks somewhat normal to me

# %%
# Separate the histogram into 40 bins
hist(river$nitrate, xlab = "Nitrate concentration", breaks = 40)
# Out:
# Plot with title "Histogram of river$nitrate"

# %%
# Apply Grubbs' test to the river nitrate data
grubbs.test(river$nitrate)
# Out:
# 	Grubbs test for one outlier
#
# data:  river$nitrate
# G = 4.72680, U = 0.92269, p-value = 0.000211
# alternative hypothesis: highest value 1.897 is an outlier

# %%
# Apply Grubbs' test to the nitrate data
grubbs.test(river$nitrate)

# Find row index of the max of the nitrate data
which.max(river$nitrate)
# Out:
# 	Grubbs test for one outlier
#
# data:  river$nitrate
# G = 4.72680, U = 0.92269, p-value = 0.000211
# alternative hypothesis: highest value 1.897 is an outlier
# [1] 156

# %%
# Apply Grubbs' test to the nitrate data
grubbs.test(river$nitrate)

# Find row index of the max of the nitrate data
which.max(river$nitrate)

# Runs Grubbs' test excluding row 156
grubbs.test(river$nitrate[-156])
# Out:
# 	Grubbs test for one outlier
#
# data:  river$nitrate
# G = 4.72680, U = 0.92269, p-value = 0.000211
# alternative hypothesis: highest value 1.897 is an outlier
# [1] 156
# 	Grubbs test for one outlier
#
# data:  river$nitrate[-156]
# G = 3.42980, U = 0.95915, p-value = 0.07756
# alternative hypothesis: highest value 1.643 is an outlier

# %% [markdown]
# # TSAD

# %% [markdown]
# #### Visual assessment of seasonality:
#
#
# The first step when analyzing time series should be to construct graphical summaries that provide insight into important features such as trend, seasonality and possible anomalies. In this exercise, you'll use several plots to explore thenitrate concentrations as a time series and to identify the period of any seasonal patterns that might be present.
#
# When plotting time series, the time variable should always appear on the x-axis.

# %%
# View contents of dataset
head(river)

# Show the time series of nitrate concentrations with time
plot(nitrate ~ index, data = river, type = "o")
# Out:
#   ï..index nitrate months   index
# 1 1        1.581   January  1
# 2 2        1.323   February 2
# 3 3        1.140   March    3
# 4 4        1.245   April    4
# 5 5        1.072   May      5
# 6 6        1.483   June     6
# plot without title

# %%
#  Calculate monthly means by completing the tapply() function 
#  call and plot the result as a time series.

# Calculate the mean nitrate by month
monthly_mean <- tapply(river$nitrate, river$months, FUN = mean)
print(monthly_mean)

# tapply requires you to specify a function that will be used to 
# calculate summary statistics (of nitrate) over each group contained
# in the grouping variable (month).

# Plot the monthly means 
plot(monthly_mean, type = "o", xlab = "Month", ylab = "Monthly mean")
# Out:
#     April    August  December  February   January      July      June     March
# 1.0166250 0.9380833 1.2264167 1.1838400 1.2163600 0.9810417 0.9792083 1.1050400
#       May  November   October September
# 0.9978333 1.0962500 1.0360000 0.9885833
# plot without title

# %%
#  Use the boxplot() to visualize overall change in nitrate concentration by 
#  months. Boxplots also provide insight into how spread out the 
#  concentrations are by month.

# %%
# Create a boxplot of nitrate against months
boxplot(nitrate ~ months, data = river)
# Out:
# plot without title

# %%
###  Seasonal Hybrid ESD algorithm:

# We have identified a repeating seasonal cycle in the nitrate data, 
# with a period of 12 months. You are now ready to apply the Seasonal-Hybrid 
# ESD algorithm to find out if there are anomalies present in the data.

# Use the AnomalyDetectionVec function to run the Hybrid-ESD algorithm over 
# the nitrate concentrations.
# You will need to specify the input arguments:

# x: a vector of values

# period: the period of any repeating pattern

# The x argument is a numeric vector that we want to check for anomalies
# The period argument is an integer for the number of time units for any repeating cycles to return to the same level.


# Run Seasonal-Hybrid ESD for nitrate concentrations

AnomalyDetectionVec(x = river$nitrate, period = 12, direction = 'both', plot = T)
# Out:
# $anoms
#   index anoms
# 1     6 1.483
# 2    53 1.533
# 3   156 1.897
#
# $plot
# plot without title

# %%
###  Interpreting Seasonal-Hybrid ESD output

# The Seasonal-Hybrid ESD algorithm provides some useful output for understanding where the anomalies occur within the data.

# In particular, the AnomalyDetectionVec() function generates output as a list with the two elements

# $anoms, a data frame containing the columns index and anoms
# $plot a plot of the time series with anomalies highlighted (if plot = T)

# Use the AnomalyDetectionVec() function to find either large or small anomalies in the river nitrate data assuming a period of 12 and set the plot flag to TRUE.
# Assign the result to a new object named river_anomalies.

# Remember that the arguments to the AnomalyDetectionVec() function are x (input data), period (period of repeating pattern), direction (whether to find large, small or both kinds of anomaly), and plot (whether or not to produce a time series plot showing anomalies).

             
# To access a named element within a list, specify the list name, followed by the $ sign, then the name of the element, for example mylist$myelement.


                                           
# Use Seasonal-Hybrid ESD for nitrate concentrations
river_anomalies <- AnomalyDetectionVec(x = river$nitrate, period = 12, direction = 'both', plot = T)

# Print the anomalies
river_anomalies$anoms

# Print the plot
print(river_anomalies$plot)
# Out:
#   index anoms
# 1   6   1.483
# 2  53   1.533
# 3 156   1.897
# plot without title
